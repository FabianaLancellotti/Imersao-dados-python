# %% [markdown]
# <a href="https://colab.research.google.com/github/FabianaLancellotti/Imersao-dados-python/blob/main/Imers%C3%A3o_Dados_com_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print("linhas:", linhas)
print("colunas:", colunas)
# Out:
# linhas: 133349
# colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.columns

mapeamento_colunas = {
    'work_year': 'ano',
    'experience_level': 'nivel_experiencia',
    'employment_type': 'tipo_emprego',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda_salario',
    'salary_in_usd': 'salario_em_usd',
    'employee_residence': 'residencia_funcionario',
    'remote_ratio': 'taxa_remoto',
    'company_location': 'localizacao_empresa',
    'company_size': 'tamanho_empresa'
}

df = df.rename(columns=mapeamento_colunas)

print("Colunas traduzidas:")
print(df.columns)
# Out:
# Colunas traduzidas:
# Index(['ano', 'nivel_experiencia', 'tipo_emprego', 'cargo', 'salario',
#        'moeda_salario', 'salario_em_usd', 'residencia_funcionario',
#        'taxa_remoto', 'localizacao_empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df["nivel_experiencia"].value_counts()
# Out:
# nivel_experiencia
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["tipo_emprego"].value_counts()
# Out:
# tipo_emprego
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df["taxa_remoto"].value_counts()
# Out:
# taxa_remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
nivel_experiencia = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Junior',
    'EX': 'Executivo'
}

df['nivel_experiencia'] = df['nivel_experiencia'].replace(nivel_experiencia)

print("Categorias de 'nivel_experiencia' traduzidas:")
print(df['nivel_experiencia'].value_counts())
# Out:
# Categorias de 'nivel_experiencia' traduzidas:
# nivel_experiencia
# Senior       77241
# Pleno        40465
# Junior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
mapeamento_tipo_emprego = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
}

df['tipo_emprego'] = df['tipo_emprego'].replace(mapeamento_tipo_emprego)

print("Categorias de 'tipo_emprego' traduzidas:")
print(df['tipo_emprego'].value_counts())
# Out:
# Categorias de 'tipo_emprego' traduzidas:
# tipo_emprego
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
mapeamento_tamanho_empresa = {
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
}

df['tamanho_empresa'] = df['tamanho_empresa'].replace(mapeamento_tamanho_empresa)

print("Categorias de 'tamanho_empresa' traduzidas:")
print(df['tamanho_empresa'].value_counts())
# Out:
# Categorias de 'tamanho_empresa' traduzidas:
# tamanho_empresa
# Médio      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
mapeamento_taxa_remoto = {
    0: 'Presencial',
    100: 'Remoto',
    50: 'Híbrido'
}

df['taxa_remoto'] = df['taxa_remoto'].replace(mapeamento_taxa_remoto)

print("Categorias de 'taxa_remoto' traduzidas:")
print(df['taxa_remoto'].value_counts())
# Out:
# Categorias de 'taxa_remoto' traduzidas:
# taxa_remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano nivel_experiencia    tipo_emprego               cargo  salario  \
# 0  2025.0            Senior  Tempo Integral  Solutions Engineer   214000
# 1  2025.0            Senior  Tempo Integral  Solutions Engineer   136000
# 2  2025.0             Pleno  Tempo Integral       Data Engineer   158800
# 3  2025.0             Pleno  Tempo Integral       Data Engineer   139200
# 4  2025.0            Junior  Tempo Integral       Data Engineer    90000
#
#   moeda_salario  salario_em_usd residencia_funcionario taxa_remoto  \
# 0           USD          214000                     US      Remoto
# 1           USD          136000                     US      Remoto
# 2           USD          158800                     AU  Presencial
# 3           USD          139200                     AU  Presencial
# 4           USD           90000                     US  Presencial
#
#   localizacao_empresa tamanho_empresa
# 0                  US           Médio
# 1                  US           Médio
# ...

# %%
df.describe(include="object")
# Out:
#        nivel_experiencia    tipo_emprego           cargo moeda_salario  \
# count             133349          133349          133349        133349
# unique                 4               4             390            26
# top               Senior  Tempo Integral  Data Scientist           USD
# freq               77241          132563           17314        126140
#
#        residencia_funcionario taxa_remoto localizacao_empresa tamanho_empresa
# count                  133349      133349              133349          133349
# unique                    102           3                  95               3
# top                        US  Presencial                  US           Médio
# freq                   119579      105312              119641          129561

# %%
df.describe()
# Out:
#                  ano       salario  salario_em_usd
# count  133339.000000  1.333490e+05   133349.000000
# mean     2024.358770  1.632833e+05   157617.272098
# std         0.680627  2.173860e+05    74288.363097
# min      2020.000000  1.400000e+04    15000.000000
# 25%      2024.000000  1.060200e+05   106000.000000
# 50%      2024.000000  1.470000e+05   146206.000000
# 75%      2025.000000  1.990000e+05   198000.000000
# max      2025.000000  3.040000e+07   800000.000000

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")
df.isnull()
# Out:
#         work_year  experience_level  employment_type  job_title  salary  \
# 0           False             False            False      False   False
# 1           False             False            False      False   False
# 2           False             False            False      False   False
# 3           False             False            False      False   False
# 4           False             False            False      False   False
# ...           ...               ...              ...        ...     ...
# 133344      False             False            False      False   False
# 133345      False             False            False      False   False
# 133346      False             False            False      False   False
# 133347      False             False            False      False   False
# 133348      False             False            False      False   False
#
#         salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# ...

# %%
df.isnull().sum()
# Out:
# work_year             10
# experience_level       0
# employment_type        0
# job_title              0
# salary                 0
# salary_currency        0
# salary_in_usd          0
# employee_residence     0
# remote_ratio           0
# company_location       0
# company_size           0
# dtype: int64

# %%
df["work_year"].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         work_year experience_level employment_type                  job_title  \
# 5588          NaN               SE              FT            Product Manager
# 59692         NaN               MI              FT                   Engineer
# 59710         NaN               EN              FT             Data Scientist
# 59759         NaN               SE              FT          Software Engineer
# 59789         NaN               SE              FT                   Engineer
# 131000        NaN               SE              FT  Machine Learning Engineer
# 131006        NaN               SE              FT     Data Analytics Manager
# 133054        NaN               EN              FT             Data Scientist
# 133281        NaN               MI              FT  Machine Learning Engineer
# 133317        NaN               MI              FT             Data Scientist
#
#         salary salary_currency  salary_in_usd employee_residence  \
# ...

# %%
import numpy as np

#Criação de um DataFrame de teste
df_salarios = pd.DataFrame({
    'nome': ["Ana", "Bruno", "Carlos", "Daniele", "Val"],
    'salario': [4000, np.nan, 5000, np.nan, 100000]
})

#Calcula a média salarial e substitui os nulos pela média, arredondando os valores
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))

#Calcula a mediana e substitui os nulos pela mediana
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

df_salarios
# Out:
#       nome   salario  salario_media  salario_mediana
# 0      Ana    4000.0        4000.00           4000.0
# 1    Bruno       NaN       36333.33           5000.0
# 2   Carlos    5000.0        5000.00           5000.0
# 3  Daniele       NaN       36333.33           5000.0
# 4      Val  100000.0      100000.00         100000.0

# %%
#Criação de um DataFrame de teste
df_temperaturas = pd.DataFrame({
    "Dia": ["Segunda", "Terça", "Quarta", "Quinta", "Sexta"],
    "Temperatura": [30, np.nan, np.nan, 28,27]
})

df_temperaturas["preenchido_ffill"] = df_temperaturas["Temperatura"].ffill()

df_temperaturas
# Out:
#        Dia  Temperatura  preenchido_ffill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              30.0
# 2   Quarta          NaN              30.0
# 3   Quinta         28.0              28.0
# 4    Sexta         27.0              27.0

# %%
#Criação de um DataFrame de teste
df_temperaturas = pd.DataFrame({
    "Dia": ["Segunda", "Terça", "Quarta", "Quinta", "Sexta"],
    "Temperatura": [30, np.nan, np.nan, 28,27]
})

df_temperaturas["preenchido_bfill"] = df_temperaturas["Temperatura"].bfill()

df_temperaturas
# Out:
#        Dia  Temperatura  preenchido_bfill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              28.0
# 2   Quarta          NaN              28.0
# 3   Quinta         28.0              28.0
# 4    Sexta         27.0              27.0

# %%
#Criação de um DataFrame de teste
df_cidades = pd.DataFrame({
    'nome': ["Ana", "Bruno", "Carlos", "Daniele", "Val"],
    'cidade': ["São Paulo", np.nan, "Curitiba", np.nan, "Belém"]
})

df_cidades['cidade_preenchida'] = df_cidades["cidade"].fillna("Não informado")

df_cidades
# Out:
#       nome     cidade cidade_preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Bruno        NaN     Não informado
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não informado
# 4      Val      Belém             Belém

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df_limpo.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133339 non-null  object
#  2   employment_type     133339 non-null  object
#  3   job_title           133339 non-null  object
#  4   salary              133339 non-null  int64
#  5   salary_currency     133339 non-null  object
#  6   salary_in_usd       133339 non-null  int64
#  7   employee_residence  133339 non-null  object
#  8   remote_ratio        133339 non-null  int64
#  9   company_location    133339 non-null  object
#  10  company_size        133339 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 12.2+ MB

# %%
df_limpo =df_limpo.assign(work_year = df_limpo['work_year'].astype(int))

# %%
df_limpo.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0       2025               SE              FT  Solutions Engineer  214000
# 1       2025               SE              FT  Solutions Engineer  136000
# 2       2025               MI              FT       Data Engineer  158800
# 3       2025               MI              FT       Data Engineer  139200
# 4       2025               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  int64
#  1   experience_level    133339 non-null  object
#  2   employment_type     133339 non-null  object
#  3   job_title           133339 non-null  object
#  4   salary              133339 non-null  int64
#  5   salary_currency     133339 non-null  object
#  6   salary_in_usd       133339 non-null  int64
#  7   employee_residence  133339 non-null  object
#  8   remote_ratio        133339 non-null  int64
#  9   company_location    133339 non-null  object
#  10  company_size        133339 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 12.2+ MB

# %%
df_limpo.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0       2025               SE              FT  Solutions Engineer  214000
# 1       2025               SE              FT  Solutions Engineer  136000
# 2       2025               MI              FT       Data Engineer  158800
# 3       2025               MI              FT       Data Engineer  139200
# 4       2025               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
experience_level = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Junior',
    'EX': 'Executivo'
}

df_limpo['experience_level'] = df_limpo['experience_level'].replace(experience_level)

print("Categorias de 'experience_level' em df_limpo traduzidas:")
print(df_limpo['experience_level'].value_counts())
# Out:
# Categorias de 'experience_level' em df_limpo traduzidas:
# experience_level
# Senior       77236
# Pleno        40462
# Junior       12441
# Executivo     3200
# Name: count, dtype: int64

# %%
df_limpo.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0       2025           Senior              FT  Solutions Engineer  214000
# 1       2025           Senior              FT  Solutions Engineer  136000
# 2       2025            Pleno              FT       Data Engineer  158800
# 3       2025            Pleno              FT       Data Engineer  139200
# 4       2025           Junior              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
mapeamento_tipo_emprego = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
}

df_limpo['employment_type'] = df_limpo['employment_type'].replace(mapeamento_tipo_emprego)

print("Categorias de 'employment_type' em df_limpo traduzidas:")
print(df_limpo['employment_type'].value_counts())
# Out:
# Categorias de 'employment_type' em df_limpo traduzidas:
# employment_type
# Tempo Integral    132553
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
mapeamento_taxa_remoto = {
    0: 'Presencial',
    100: 'Remoto',
    50: 'Híbrido'
}

df_limpo['remote_ratio'] = df_limpo['remote_ratio'].replace(mapeamento_taxa_remoto)

print("Categorias de 'remote_ratio' em df_limpo traduzidas:")
print(df_limpo['remote_ratio'].value_counts())
# Out:
# Categorias de 'remote_ratio' em df_limpo traduzidas:
# remote_ratio
# Presencial    105305
# Remoto         27716
# Híbrido          318
# Name: count, dtype: int64

# %%
mapeamento_tamanho_empresa = {
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
}

df_limpo['company_size'] = df_limpo['company_size'].replace(mapeamento_tamanho_empresa)

print("Categorias de 'company_size' em df_limpo traduzidas:")
print(df_limpo['company_size'].value_counts())
# Out:
# Categorias de 'company_size' em df_limpo traduzidas:
# company_size
# Médio      129554
# Grande       3571
# Pequeno       214
# Name: count, dtype: int64

# %%
df_limpo.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0       2025           Senior  Tempo Integral  Solutions Engineer  214000
# 1       2025           Senior  Tempo Integral  Solutions Engineer  136000
# 2       2025            Pleno  Tempo Integral       Data Engineer  158800
# 3       2025            Pleno  Tempo Integral       Data Engineer  139200
# 4       2025           Junior  Tempo Integral       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence remote_ratio  \
# 0             USD         214000                 US       Remoto
# 1             USD         136000                 US       Remoto
# 2             USD         158800                 AU   Presencial
# 3             USD         139200                 AU   Presencial
# 4             USD          90000                 US   Presencial
#
#   company_location company_size
# 0               US        Médio
# 1               US        Médio
# ...

# %%
mapeamento_colunas = {
    'work_year': 'ano',
    'experience_level': 'nivel_experiencia',
    'employment_type': 'tipo_emprego',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'localizacao_empresa',
    'company_size': 'tamanho_empresa'
}

df_limpo = df_limpo.rename(columns=mapeamento_colunas)

print("Colunas do df_limpo traduzidas:")
print(df_limpo.columns)
# Out:
# Colunas do df_limpo traduzidas:
# Index(['ano', 'nivel_experiencia', 'tipo_emprego', 'cargo', 'salario', 'moeda',
#        'usd', 'residencia', 'remoto', 'localizacao_empresa',
#        'tamanho_empresa'],
#       dtype='object')

# %%
df_limpo.head()
# Out:
#     ano nivel_experiencia    tipo_emprego               cargo  salario moeda  \
# 0  2025            Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025            Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025             Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025             Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025            Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto localizacao_empresa tamanho_empresa
# 0  214000         US      Remoto                  US           Médio
# 1  136000         US      Remoto                  US           Médio
# 2  158800         AU  Presencial                  AU           Médio
# 3  139200         AU  Presencial                  AU           Médio
# 4   90000         US  Presencial                  US           Médio

# %%
df_limpo['nivel_experiencia'].value_counts().plot(kind='bar', title='Distribuição de senioridade')
# Out:
# <Axes: title={'center': 'Distribuição de senioridade'}, xlabel='nivel_experiencia'>

# %%
import seaborn as sns

# %%
sns.barplot(data=df_limpo, x='nivel_experiencia', y='usd')
# Out:
# <Axes: xlabel='nivel_experiencia', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='nivel_experiencia', y='usd')
plt.title('Salário médio por senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual (USD)')
plt.show()

# %%
#Média anual dos salários por nível de senioridade
df_limpo.groupby('nivel_experiencia')['usd'].mean().sort_values(ascending=False)
# Out:
# nivel_experiencia
# Executivo    202027.667813
# Senior       172850.838301
# Pleno        143044.845979
# Junior        99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby('nivel_experiencia')['usd'].mean().sort_values(ascending=False).index
ordem
# Out:
# Index(['Executivo', 'Senior', 'Pleno', 'Junior'], dtype='object', name='nivel_experiencia')

# %%
#Gráfico de barras do Salário médio por senioridade
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='nivel_experiencia', y='usd', order=ordem)
plt.title('Salário médio por senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual (USD)')
plt.show()

# %%
#Histograma da Distribuição dos salários anuais
plt.figure(figsize=(8,4))
#bins= Largura das barras | kde= linha azul que contorna o gráfico
sns.histplot(df_limpo['usd'], bins=50, kde=True)
plt.title('Distribuição dos salários anuais')
plt.xlabel('Salário em USD')
plt.ylabel('Frequência')
plt.show()

# %%
#Histograma da Distribuição dos salários anuais
#Alteração do valor de figsize (de 8,4 para 10,5)
plt.figure(figsize=(10,5))
sns.histplot(df_limpo['usd'], bins=50, kde=True)
plt.title('Distribuição dos salários anuais')
plt.xlabel('Salário em USD')
plt.ylabel('Frequência')
plt.show()

# %%
#Boxplot
plt.figure(figsize=(8,4))
sns.boxplot(x=df_limpo['usd'])
plt.title('Boxplot Salário')
plt.xlabel('Salário em USD')
plt.show()

# %%
#Boxplot por senioridade
ordem_senioridade = ["Junior", "Pleno", "Senior", "Executivo"]
plt.figure(figsize=(8,5))
sns.boxplot(x='nivel_experiencia', y='usd', data=df_limpo, order=ordem_senioridade)
plt.title('Boxplot da distribuição por senioridade')
plt.xlabel('Salário em USD')
plt.show()

# %%
#Boxplot por senioridade
#Colorindo cada caixinha
ordem_senioridade = ["Junior", "Pleno", "Senior", "Executivo"]
plt.figure(figsize=(8,5))
sns.boxplot(x='nivel_experiencia', y='usd', data=df_limpo, order=ordem_senioridade, palette='Set2', hue='nivel_experiencia')
plt.title('Boxplot da distribuição por senioridade')
plt.xlabel('Salário em USD')
plt.show()

# %%
import plotly.express as px

# %%
#Prompt IA: Crie um gráfico de média salarial por senioridade em barras usando o plotly
df_media_salario = df_limpo.groupby('nivel_experiencia')['usd'].mean().sort_values(ascending=False).reset_index()

fig = px.bar(df_media_salario,
    x='nivel_experiencia',
    y='usd',
    title='Salário médio anual por senioridade (USD)',
    labels={'nivel_experiencia': 'Nível de Experiência', 'usd': 'Salário Médio Anual (USD)'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
   #color='nivel_experiencia', # Para colorir cada barra por senioridade
   #color_discrete_sequence=px.colors.qualitative.Pastel # Escolha de uma paleta de cores

   #fig.update_layout(xaxis={'categoryorder':'array', 'categoryarray':df_media_salario['nivel_experiencia']})

   #Prompt IA: Crie um gráfico de média salarial por senioridade em barras usando o plotly
df_media_salario = df_limpo.groupby('nivel_experiencia')['usd'].mean().sort_values(ascending=False).reset_index()

fig = px.bar(df_media_salario,
    x='nivel_experiencia',
    y='usd',
    title='Salário médio anual por senioridade (USD)',
    labels={'nivel_experiencia': 'Nível de Experiência', 'usd': 'Salário Médio Anual (USD)'},
    color='nivel_experiencia', # Para colorir cada barra por senioridade
    color_discrete_sequence=px.colors.qualitative.Pastel) # Escolha de uma paleta de cores

fig.update_layout(xaxis={'categoryorder':'array', 'categoryarray':df_media_salario['nivel_experiencia']})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Criação de gráfico de pizza para tipo de trabalho

remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
                 values='quantidade',
                 title='Proporção dos Tipos de Trabalho')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Converter o gráfico para rosca

remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
              values='quantidade',
              title='Proporção dos Tipos de Trabalho',
             hole= 0.5)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Para incluir a porcentagem + Label (nome das categorias) no gráfico de rosca

remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
              values='quantidade',
              title='Proporção dos Tipos de Trabalho',
             hole= 0.5)

fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#DESAFIO: Criar um gráfico interativo com a média salarial por localização_empresa para o cargo Data Scientist usando plotly. (Usado a IA para gerar esse gráfico)

df_data_scientist = df_limpo[df_limpo['cargo'] == 'Data Scientist']
df_media_salario_localizacao = df_data_scientist.groupby('localizacao_empresa')['usd'].mean().sort_values(ascending=False).reset_index()

fig = px.bar(
    df_media_salario_localizacao,
    x='localizacao_empresa',
    y='usd',
    title='Média Salarial para Data Scientists por País (USD)',
    labels={'localizacao_empresa': 'País', 'usd': 'Salário Médio Anual (USD)'},
    color='localizacao_empresa',
    color_discrete_sequence=px.colors.qualitative.Pastel
)

fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head()
# Out:
#     ano nivel_experiencia    tipo_emprego               cargo  salario moeda  \
# 0  2025            Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025            Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025             Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025             Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025            Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto localizacao_empresa tamanho_empresa
# 0  214000         US      Remoto      Estados Unidos           Médio
# 1  136000         US      Remoto      Estados Unidos           Médio
# 2  158800         AU  Presencial           Austrália           Médio
# 3  139200         AU  Presencial           Austrália           Médio
# 4   90000         US  Presencial      Estados Unidos           Médio

# %%
pip install pycountry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 53.7 MB/s eta 0:00:00
# ...

# %%
import pycountry

# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head()
# Out:
#     ano nivel_experiencia    tipo_emprego               cargo  salario moeda  \
# 0  2025            Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025            Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025             Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025             Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025            Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto localizacao_empresa tamanho_empresa  \
# 0  214000         US      Remoto      Estados Unidos           Médio
# 1  136000         US      Remoto      Estados Unidos           Médio
# 2  158800         AU  Presencial           Austrália           Médio
# 3  139200         AU  Presencial           Austrália           Médio
# 4   90000         US  Presencial      Estados Unidos           Médio
#
#   residencia_iso3
# 0             USA
# 1             USA
# 2             AUS
# ...

# %%
df_limpo.to_csv('dados-imersao-final.csv', index=False)
